# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Dataset/overview.csv")

# %%
new_df = df[["Map", "Player", "Team", "Agents", "Rating", "Average Combat Score"]]

# %%
new_df
# Out:
#           Map    Player   Team     Agents  Rating  Average Combat Score
# 0      Ascent     mazin   MIBR       omen    1.13                   251
# 1      Ascent    artzin   MIBR       yoru    1.04                   224
# 2      Ascent   ShahZaM   MIBR       sova    0.92                   170
# 3      Ascent    liazzi   MIBR    killjoy    0.90                   159
# 4      Ascent     Pa1nt   MIBR        iso    0.68                   148
# ...       ...       ...    ...        ...     ...                   ...
# 10175    Bind   t3xture  Gen.G       raze    1.60                   291
# 10176    Bind    Meteor  Gen.G     cypher    1.43                   269
# 10177    Bind     Karon  Gen.G  brimstone    1.20                   217
# 10178    Bind  Munchkin  Gen.G      viper    1.04                   196
# 10179    Bind     Lakia  Gen.G       skye    1.02                   147
#
# [10180 rows x 6 columns]

# %%
stage = pd.read_csv("Dataset/maps_scores.csv")
stage
# Out:
#                                  Tournament           Stage   Match Type  \
# 0     Champions Tour 2024: Americas Stage 2  Regular Season       Week 1
# 1     Champions Tour 2024: Americas Stage 2  Regular Season       Week 1
# 2     Champions Tour 2024: Americas Stage 2  Regular Season       Week 1
# 3     Champions Tour 2024: Americas Stage 2  Regular Season       Week 1
# 4     Champions Tour 2024: Americas Stage 2  Regular Season       Week 1
# ...                                     ...             ...          ...
# 1013   Champions Tour 2024: Pacific Kickoff        Playoffs   Semifinals
# 1014   Champions Tour 2024: Pacific Kickoff        Playoffs  Grand Final
# 1015   Champions Tour 2024: Pacific Kickoff        Playoffs  Grand Final
# 1016   Champions Tour 2024: Pacific Kickoff        Playoffs  Grand Final
# 1017   Champions Tour 2024: Pacific Kickoff        Playoffs  Grand Final
#
#                     Match Name     Map     Team A  Team A Score  \
# ...

# %%
new_stage = stage[["Team A Score", "Team B Score", "Team A", "Team B"]]
new_stage
# Out:
#       Team A Score  Team B Score     Team A       Team B
# 0                9            13       MIBR     Leviatán
# 1                7            13       MIBR     Leviatán
# 2               13             8  Sentinels  NRG Esports
# 3               14            12  Sentinels  NRG Esports
# 4               14            12      FURIA  100 Thieves
# ...            ...           ...        ...          ...
# 1013             8            13        DRX        Gen.G
# 1014             5            13  Paper Rex        Gen.G
# 1015            13             4  Paper Rex        Gen.G
# 1016            11            13  Paper Rex        Gen.G
# 1017             4            13  Paper Rex        Gen.G
#
# [1018 rows x 4 columns]

# %%
new_stage["Winner"] = new_stage["Team A"] if int(new_stage["Team A Score"]) > int(new_stage["Team B Score"]) else new_stage["Team "]
new_stage
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 new_stage["Winner"] = new_stage["Team A"] if int(new_stage["Team A Score"]) > int(new_stage["Team B Score"]) else new_stage["Team "]
#       2 new_stage
#
# File c:\Users\lelin\miniconda3\envs\hackathon\Lib\site-packages\pandas\core\series.py:248, in _coerce_method.<locals>.wrapper(self)
#     240     warnings.warn(
#     241         f"Calling {converter.__name__} on a single element Series is "
#     242         "deprecated and will raise a TypeError in the future. "
#    (...)
#     245         stacklevel=find_stack_level(),
#     246     )
#     247     return converter(self.iloc[0])
# --> 248 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'int'>
